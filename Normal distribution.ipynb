# %% [markdown]
# # Normal distribution

# %%
from scipy.integrate import quad as integrate
from scipy.special import binom
from scipy.optimize import fsolve as solve
import numpy as np
from numpy import sqrt, sin, cos, pi, exp, inf, round, ceil
from numpy import array as arr

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()

def fig():
    return figure(plot_width=950, plot_height=500)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="24e1aa24-5ac1-4754-9b1e-cfebb16e2b2d">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Define the normal distribution:

# %%
def normal_distribution(mu, sigma):
    def f(x):
        return 1/sqrt(2*pi*sigma**2)*exp(-(x-mu)**2/(2*sigma**2))
    return f

# %%
integrate(normal_distribution(12,3), -inf, inf)
# Out:
# (0.9999999999999984, 1.6699038772828793e-09)

# %% [markdown]
# Define the binomial distribution:

# %%
def binomial_distribution(n):
    def f(x):
        return binom(n,x)*(1/2)**n
    return f

# %% [markdown]
# Define our specific cases:

# %%
n = 20 # Up until now, only works for even n
mu = int(n/2)

bin = binomial_distribution(n)

sigma = sqrt(sum(bin(x)*(mu-x)**2 for x in range(n+1)))

norm = normal_distribution(mu, sigma)

# %% [markdown]
# Some basic plots:

# %%
x_norm = np.linspace(-1, n+1, 1000)
y_norm = norm(x_norm)

x_bin = np.linspace(0,n,n+1)
y_bin = bin(x_bin)

# %%
p = fig()
p.line(x_norm, y_norm)
p.vbar(x_bin, top=y_bin, width=0.8)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="76002161-d622-476a-aa1e-7d17cbd08a4b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("76002161-d622-476a-aa1e-7d17cbd08a4b");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("76002161-d622-476a-aa1e-7d17cbd08a4b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '76002161-d622-476a-aa1e-7d17cbd08a4b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"56ad1dd0-6c04-4681-adcf-d8d6fe04b6fe":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"aa866d5e-f04c-4e42-9139-784b043e9d42","type":"BoxAnnotation"},{"attributes":{"dimension":1,"plot":{"id":"3401f600-3dd9-4bed-9409-9d1a1c19d6bb","subtype":"Figure","type":"Plot"},"ticker":{"id":"873d70bb-16cf-4375-8d4b-14f19f690d05","type":"BasicTicker"}},"id":"86e6c3d7-e322-4f35-9bbe-36a29120ce71","type":"Grid"},{"attributes":{"formatter":{"id":"8241ad97-2cfe-4219-b16d-15ce9ebbf607","type":"BasicTickFormatter"},"plot":{"id":"3401f600-3dd9-4bed-9409-9d1a1c19d6bb","subtype":"Figure","type":"Plot"},"ticker":{"id":"873d70bb-16cf-4375-8d4b-14f19f690d05","type":"BasicTicker"}},"id":"3b73331a-d510-4c19-8bfe-8676a608b274","type":"LinearAxis"},{"attributes":{"plot":{"id":"3401f600-3dd9-4bed-9409-9d1a1c19d6bb","subtype":"Figure","type":"Plot"},"ticker":{"id":"cab217b4-75a7-4a69-85ff-c95afa4ea192","type":"BasicTicker"}},"id":"e637ebb8-de53-42e1-ae16-3f8fa65f3474","type":"Grid"},{"attributes":{"overlay":{"id":"aa866d5e-f04c-4e42-9139-784b043e9d42","type":"BoxAnnotation"},"plot":{"id":"3401f600-3dd9-4bed-9409-9d1a1c19d6bb","subtype":"Figure","type":"Plot"}},"id":"c08a0608-5df9-4d21-b61a-44efc07cbb27","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"c41f11b0-23ed-45b5-84d1-b941fa9ae002","type":"DataRange1d"},{"attributes":{"plot":{"id":"3401f600-3dd9-4bed-9409-9d1a1c19d6bb","subtype":"Figure","type":"Plot"}},"id":"535bd3dc-8dca-4ac4-bd55-31626dc7fe54","type":"WheelZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"df27b8b5-ef81-41e0-b60b-ea981dbab0fd","type":"Line"},{"attributes":{"callback":null,"column_names":["x","top"],"data":{"top":{"__ndarray__":"AAAAAAAAsD4AAAAAAAD0PgAAAAAAwCc/AAAAAADQUT8AAAAAAO1yPwAAAAAASI4/AAAAAADtoj8AAAAAAO2yPwAAAAAgwb4/AAAAAMCAxD8AAAAAoI3GPwAAAADAgMQ/AAAAACDBvj8AAAAAAO2yPwAAAAAA7aI/AAAAAABIjj8AAAAAAO1yPwAAAAAA0FE/AAAAAADAJz8AAAAAAAD0PgAAAAAAALA+","dtype":"float64","shape":[21]},"x":{"__ndarray__":"AAAAAAAAAAAAAAAAAADwPwAAAAAAAABAAAAAAAAACEAAAAAAAAAQQAAAAAAAABRAAAAAAAAAGEAAAAAAAAAcQAAAAAAAACBAAAAAAAAAIkAAAAAAAAAkQAAAAAAAACZAAAAAAAAAKEAAAAAAAAAqQAAAAAAAACxAAAAAAAAALkAAAAAAAAAwQAAAAAAAADFAAAAAAAAAMkAAAAAAAAAzQAAAAAAAADRA","dtype":"float64","shape":[21]}}},"id":"2312dff7-05dd-47bb-89b2-aee18c923416","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"004c6328-b05d-436f-a702-7ce003370838","type":"ColumnDataSource"},"glyph":{"id":"90667389-575a-4623-ba4a-daea9c5b77d8","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"df27b8b5-ef81-41e0-b60b-ea981dbab0fd","type":"Line"},"selection_glyph":null},"id":"072fb5d3-fa7a-4e65-988a-f3cea3fd241d","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"3401f600-3dd9-4bed-9409-9d1a1c19d6bb","subtype":"Figure","type":"Plot"}},"id":"fb9fc951-e76e-42ee-9945-248cdd2edd3f","type":"PanTool"},{"attributes":{"plot":{"id":"3401f600-3dd9-4bed-9409-9d1a1c19d6bb","subtype":"Figure","type":"Plot"}},"id":"bbf09afa-de15-460a-873d-664d064ebcb9","type":"ResetTool"},{"attributes":{"plot":null,"text":""},"id":"12976fbd-cfa9-416c-ba59-356b5a356130","type":"Title"},{"attributes":{},"id":"873d70bb-16cf-4375-8d4b-14f19f690d05","type":"BasicTicker"},{"attributes":{"plot":{"id":"3401f600-3dd9-4bed-9409-9d1a1c19d6bb","subtype":"Figure","type":"Plot"}},"id":"4678d4e1-c181-47de-9e6a-0eb502f2c67c","type":"SaveTool"},{"attributes":{"formatter":{"id":"93d73850-786a-4286-afc6-0c6d827d13c4","type":"BasicTickFormatter"},"plot":{"id":"3401f600-3dd9-4bed-9409-9d1a1c19d6bb","subtype":"Figure","type":"Plot"},"ticker":{"id":"cab217b4-75a7-4a69-85ff-c95afa4ea192","type":"BasicTicker"}}," ...

# %% [markdown]
# ### Finding the corresponding intervals
# The next step is to find out the intervals of the normal distribution whose integrals yield the same values as the binomial distribution for the corresponding $x$.
#
# The function ``integ_around`` returns
# $$ \int^{\mu+a}_{\mu-a} f(x) \;dx$$
# as a function of $a$ for the given $\mu$ where $f(x)$ is the normal distribution. Optionally fixed upper or lower bounds can be passed.

# %%
def integ_around(val, upper_bound=False, lower_bound=False):
    # Create function
    def f(a):
        # Set upper and lower bounds depending on whether they are specified or not
        upper = val+a if not upper_bound else upper_bound
        lower = val-a if not lower_bound else lower_bound
        # Return value of integral
        return integrate(norm, lower, upper)
    return f

# %% [markdown]
# The function ``diff_to_integ`` returns a function of $a$ which gives the difference of the bionmial distribution at the given $\mu$ and the integral $ \int^{\mu+a}_{\mu-a} f(x) \;dx$. Here again optionally fixed upper or lower bounds can be passed.

# %%
def diff_to_integ(val, upper_bound=False, lower_bound=False):
    integ = integ_around(val, upper_bound, lower_bound)
    def f(a):
        return integ(a) - bin(val)
    return f

# %% [markdown]
# Next, we have to find the zeros of ``diff_to_integ`` for different $\mu$.
#
# The interval endpoints are collected in the array ``intervals``.

# %%
intervals = []

# The first
a = solve(diff_to_integ(mu), 0)[0]
intervals.append(mu+a)

# The rest
for val in range(mu+1, n):
    lower_bound = intervals[-1]
    a = solve(diff_to_integ(val, lower_bound=lower_bound), 0)[0]
    intervals.append(val+a)

# %%
intervals
# Out:
# [10.497874815138442,
#  11.496107575745944,
#  12.501972300399022,
#  13.521207990540706,
#  14.560700324772521,
#  15.629378769106374,
#  16.73989052048239,
#  17.912263047995339,
#  19.183902573892187,
#  20.650394089291296]

# %%
other_side = n - arr(intervals)[::-1]
intervals = np.concatenate((other_side, intervals))

# %% [markdown]
# Now, let us take a look at how it looks.

# %%
p = fig()
p.line(x_norm, y_norm)
p.vbar(intervals, top=norm(intervals), width=0.02)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a249fc9d-412d-4eef-b9ea-9749a1b96e4c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a249fc9d-412d-4eef-b9ea-9749a1b96e4c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a249fc9d-412d-4eef-b9ea-9749a1b96e4c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a249fc9d-412d-4eef-b9ea-9749a1b96e4c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7801f542-826b-45f4-99cf-9357d9b56681":{"roots":{"references":[{"attributes":{},"id":"7a5ddadb-a5ce-472d-9d0b-03a774fdd8cc","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.02},"x":{"field":"x"}},"id":"d8fe07d3-ce85-405d-9892-d50b5e1a89fc","type":"VBar"},{"attributes":{"plot":{"id":"171d3f2c-a3d9-4f0b-9c30-c6e46a48261d","subtype":"Figure","type":"Plot"}},"id":"eb79498d-857f-4fd8-a60b-d8de9a4493af","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"68e641d9-13a7-4c5b-ad82-a9cd8dfd9976","type":"BoxAnnotation"},"plot":{"id":"171d3f2c-a3d9-4f0b-9c30-c6e46a48261d","subtype":"Figure","type":"Plot"}},"id":"d208c1b0-0a3e-48d9-b8cf-8e8761261459","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["x","top"],"data":{"top":{"__ndarray__":"etz7Cpu8wT70X0A3lFIEP92xisKgVjY/eFi+yD0eXz/jO+ok7bl+P/3oTBb20pY/aQbhDvRvqj/i0T2zVmy4P4AJtkm/QcI/FoA/ZRVHxj8WgD9lFUfGP4AJtkm/QcI/4tE9s1ZsuD9pBuEO9G+qP/3oTBb20pY/4zvqJO25fj94WL7IPR5fP92xisKgVjY/9F9AN5RSBD963PsKm7zBPg==","dtype":"float64","shape":[20]},"x":{"__ndarray__":"AJLgQwfQ5L9gc29ZeB3qPwAWXG6vswBAAENfR7QUCkDIkMchhHsRQFb7KMbXwRVA7NrYc0jqGUA8Jyn5+v0dQCW/FTD+ASFA6vRejRYBI0AWC6Fy6f4kQNtA6s8B/iZAYmxrgwIBKUCKkhPG2worQFWC6xwUHy1AnDcc7z1CL0CgFxR3ab0wQEB9NBKK6TFAZYQ0PRQvM0CQBB86gKY0QA==","dtype":"float64","shape":[20]}}},"id":"ae23f558-c9ac-49a0-8493-aafa3594b09f","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"2d8e5c4d-b354-415c-8b73-88d6f604bc3c","type":"ColumnDataSource"},"glyph":{"id":"c314431d-4792-4560-845a-dbb7e1338d9d","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"ff5db9b1-ee19-4d2a-ab3a-cfbaefd09af7","type":"Line"},"selection_glyph":null},"id":"d0238d90-c615-469b-b702-2a341cdb1e20","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.02},"x":{"field":"x"}},"id":"34c05cfc-3cae-419f-aaa4-cec1609ef68b","type":"VBar"},{"attributes":{"data_source":{"id":"ae23f558-c9ac-49a0-8493-aafa3594b09f","type":"ColumnDataSource"},"glyph":{"id":"d8fe07d3-ce85-405d-9892-d50b5e1a89fc","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"34c05cfc-3cae-419f-aaa4-cec1609ef68b","type":"VBar"},"selection_glyph":null},"id":"d8e76811-bfb8-4353-8c45-7664ef9a893b","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"171d3f2c-a3d9-4f0b-9c30-c6e46a48261d","subtype":"Figure","type":"Plot"}},"id":"27a387d5-2c1b-4068-b110-bef10ff319eb","type":"HelpTool"},{"attributes":{"plot":{"id":"171d3f2c-a3d9-4f0b-9c30-c6e46a48261d","subtype":"Figure","type":"Plot"}},"id":"14772e5f-c3ad-4863-9311-c068f70a6e83","type":"PanTool"},{"attributes":{"plot":{"id":"171d3f2c-a3d9-4f0b-9c30-c6e46a48261d","subtype":"Figure","type":"Plot"}},"id":"253a4819-73b6-4d69-8a8e-2f8f9148a286","type":"ResetTool"},{"attributes":{"plot":{"id":"171d3f2c-a3d9-4f0b-9c30-c6e46a48261d","subtype":"Figure","type":"Plot"}},"id":"f1ac3939-1bd8-4398-9651-7252c5984fd1","type":"SaveTool"},{"attributes":{"formatter":{"id":"eca29e8e-6a80-42b7-b218-e456ad20a072","type":"BasicTickFormatter"},"plot":{"id":"171d3f2c-a3d9-4f0b-9c30-c6e46a48261d","subtype":"Figure","type":"Plot"},"ticker":{"id":"e5c8c877-dc60-4e0e-b05a-ed30d5f0ce9e","type":"BasicTicker"}},"id":"6e1232cb-9986-4a29-86cd-494c9bdf7242","type":"LinearAxis"},{"attributes":{},"id":"e5c8c877-dc60-4e0e-b05a-ed30d5f0ce9e","type":"BasicTicker"},{"attributes":{},"id":"88775b17-9e13-40b9-a8af-a021a8c67810","type":"BasicTicker"},{"attributes":{"plot":{"id":"171d3f2c-a3d9-4f0b-9c30-c6e46a48261d","subtype":"Figure","type":"Plot"},"ticker":{"id":"e5c8c877-dc60-4e0e-b05a-ed30d5f0ce9e","type":"BasicTicker"}},"id":"1fa2242e-92c8-4050-a3d3-338c82aeab8b","type":"Grid"},{"attributes":{"formatter":{"id":"7a5ddadb-a5ce-472d-9d0b-03a774fdd8cc","type":"BasicTickFormatter"},"plot ...

# %% [markdown]
# Seems to be quite sensible. Now, let us change the standard deviation of the normal distribution, but compute the integrals with the same upper and lower bounds respectively.

# %%
# "nnorm" for "narrower norm" or "new norm" as one prefers
nnorm = normal_distribution(n/2, 3)

# %%
x_nnorm = np.linspace(-1, n+1, 1000)
y_nnorm = nnorm(x_nnorm)

p = fig()
p.line(x_nnorm, y_nnorm)
p.vbar(intervals, top=nnorm(intervals), width=0.02)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b02146d4-02e4-43a4-8632-744eb0d031d2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b02146d4-02e4-43a4-8632-744eb0d031d2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b02146d4-02e4-43a4-8632-744eb0d031d2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b02146d4-02e4-43a4-8632-744eb0d031d2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c36bc9ff-7abc-4136-943f-d935bb9b8018":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"a1e62761-c645-4dc8-b062-0623ef10c250","type":"PanTool"},{"id":"041cf3e8-ee15-43e7-9ba3-ce29f03d6228","type":"WheelZoomTool"},{"id":"caf12604-7509-4ebb-b791-2fd5cca0f8fa","type":"BoxZoomTool"},{"id":"a79609bf-1d6f-49b8-b3a2-00cf2e8d10a5","type":"SaveTool"},{"id":"a0d4c40a-1647-418f-a12a-a1a968eeeba1","type":"ResetTool"},{"id":"3aa8530b-370b-4a8f-aac5-7fdd15c5af8a","type":"HelpTool"}]},"id":"8dc4ca4a-2c49-408b-a6c1-a877f0a46233","type":"Toolbar"},{"attributes":{"callback":null},"id":"49a8bb32-1e5e-4a64-89e0-6cae20d18ec3","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","top"],"data":{"top":{"__ndarray__":"MHXBh7bzLz8HEtOwpBlUP6Rt+Nlr0HA/2ScxcBfVhT/c7s3+M2qXPz3FDn5scKU/pmzg7V8YsT8PGe2hFQu4PyjanA/4D74/ecm0zerJwD95ybTN6snAPyjanA/4D74/DxntoRULuD+mbODtXxixPz3FDn5scKU/3O7N/jNqlz/ZJzFwF9WFP6Rt+Nlr0HA/BxLTsKQZVD8wdcGHtvMvPw==","dtype":"float64","shape":[20]},"x":{"__ndarray__":"AJLgQwfQ5L9gc29ZeB3qPwAWXG6vswBAAENfR7QUCkDIkMchhHsRQFb7KMbXwRVA7NrYc0jqGUA8Jyn5+v0dQCW/FTD+ASFA6vRejRYBI0AWC6Fy6f4kQNtA6s8B/iZAYmxrgwIBKUCKkhPG2worQFWC6xwUHy1AnDcc7z1CL0CgFxR3ab0wQEB9NBKK6TFAZYQ0PRQvM0CQBB86gKY0QA==","dtype":"float64","shape":[20]}}},"id":"d98b3901-9113-43c0-bf65-3682a6b9afb9","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"2ad58f3a-9782-42a1-9794-02bdeb91ae57","subtype":"Figure","type":"Plot"},"ticker":{"id":"87523718-319a-4e45-a96f-4f34119801a1","type":"BasicTicker"}},"id":"569a6531-80a7-4a85-8afe-2b6f05e0b46a","type":"Grid"},{"attributes":{},"id":"87523718-319a-4e45-a96f-4f34119801a1","type":"BasicTicker"},{"attributes":{},"id":"a0fb004a-25ec-4aa3-82dd-85022097e7e9","type":"BasicTicker"},{"attributes":{"plot":{"id":"2ad58f3a-9782-42a1-9794-02bdeb91ae57","subtype":"Figure","type":"Plot"}},"id":"a0d4c40a-1647-418f-a12a-a1a968eeeba1","type":"ResetTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e26d317f-2f1e-4374-976a-1f73a73ff48a","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"2ad58f3a-9782-42a1-9794-02bdeb91ae57","subtype":"Figure","type":"Plot"},"ticker":{"id":"a0fb004a-25ec-4aa3-82dd-85022097e7e9","type":"BasicTicker"}},"id":"21251071-e497-4497-8c90-3eca06095648","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"4882b7c8-76ea-4a3d-9c42-5ff2af2f636f","type":"BoxAnnotation"},{"attributes":{"plot":null,"text":""},"id":"a9a41ba9-6296-41ea-a3a8-d70205c99bc2","type":"Title"},{"attributes":{"overlay":{"id":"4882b7c8-76ea-4a3d-9c42-5ff2af2f636f","type":"BoxAnnotation"},"plot":{"id":"2ad58f3a-9782-42a1-9794-02bdeb91ae57","subtype":"Figure","type":"Plot"}},"id":"caf12604-7509-4ebb-b791-2fd5cca0f8fa","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":"5c78977c-6e9c-44b7-927e-99ed62b7d8f0","type":"ColumnDataSource"},"glyph":{"id":"e26d317f-2f1e-4374-976a-1f73a73ff48a","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f87dee7e-15f9-40b6-95bf-d62bc148d9c2","type":"Line"},"selection_glyph":null},"id":"00c7e3c0-6e3a-4840-b305-fe329fef444c","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"2ad58f3a-9782-42a1-9794-02bdeb91ae57","subtype":"Figure","type":"Plot"}},"id":"a1e62761-c645-4dc8-b062-0623ef10c250","type":"PanTool"},{"attributes":{"plot":{"id":"2ad58f3a-9782-42a1-9794-02bdeb91ae57","subtype":"Figure","type":"Plot"}},"id":"a79609bf-1d6f-49b8-b3a2-00cf2e8d10a5","type":"SaveTool"},{"attributes":{"plot":{"id":"2ad58f3a-9782-42a1-9794-02bdeb91ae57","subtype":"Figure","type":"Plot"}},"id":"041cf3e8-ee15-43e7-9ba3-ce29f03d6228","type":"WheelZoomTool"},{"attribut ...

# %% [markdown]
# Let us add $\pm\infty$ to the list of intervals in order for it to be comprehensive:

# %%
intervals = list(intervals)
intervals.insert(0, -inf)
intervals.append(inf)

# %%
vals = []
for i in range(len(intervals)-1):
    vals.append(integrate(nnorm, intervals[i], intervals[i+1])[0])

# %%
p = fig()
p.line(x_nnorm, y_nnorm)
p.vbar(x_bin, top=vals, width=0.8)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ffbc77e9-f3d1-40d6-9b00-689638c2364a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("ffbc77e9-f3d1-40d6-9b00-689638c2364a");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ffbc77e9-f3d1-40d6-9b00-689638c2364a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ffbc77e9-f3d1-40d6-9b00-689638c2364a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"bff4fb67-612f-4a1e-b61c-832f2cb763be":{"roots":{"references":[{"attributes":{"plot":null,"text":""},"id":"6c48aee9-1728-41c1-a0d8-28a6c950970c","type":"Title"},{"attributes":{},"id":"605edd31-af5a-4760-b0a9-b9e529dc57db","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"top":{"field":"top"},"width":{"value":0.8},"x":{"field":"x"}},"id":"3d616227-24c8-4c9d-a6d6-5c6e8720a315","type":"VBar"},{"attributes":{"data_source":{"id":"15e1d171-2ab5-40e8-84cb-d6fbb761f174","type":"ColumnDataSource"},"glyph":{"id":"d0f8cde0-5f22-48c2-8764-d3db238cd8f7","type":"VBar"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"3d616227-24c8-4c9d-a6d6-5c6e8720a315","type":"VBar"},"selection_glyph":null},"id":"5d8411b2-52df-479d-81f7-d145b1a9a504","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"5653c4d2-80ba-461d-9203-28692eb81312","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"4558ba12-0491-4d56-afbe-90b54ee9630d","type":"LinearAxis"}],"left":[{"id":"37e6708f-bd47-4e5d-9a59-d2e162d5a283","type":"LinearAxis"}],"plot_height":500,"plot_width":950,"renderers":[{"id":"4558ba12-0491-4d56-afbe-90b54ee9630d","type":"LinearAxis"},{"id":"dd18e947-ff7c-4082-a5b3-16f0c29bf9ec","type":"Grid"},{"id":"37e6708f-bd47-4e5d-9a59-d2e162d5a283","type":"LinearAxis"},{"id":"3550ddfd-f01e-4077-97c6-7f3f83136ed9","type":"Grid"},{"id":"a68cd535-c818-4dea-affd-9ad41bc40e57","type":"BoxAnnotation"},{"id":"edb6fb21-870c-4399-acd5-44a1c7f60fc3","type":"GlyphRenderer"},{"id":"5d8411b2-52df-479d-81f7-d145b1a9a504","type":"GlyphRenderer"}],"title":{"id":"6c48aee9-1728-41c1-a0d8-28a6c950970c","type":"Title"},"tool_events":{"id":"7900588e-37ff-4950-8adb-2f904bf6e4f6","type":"ToolEvents"},"toolbar":{"id":"11abcdf8-b36d-418e-bce9-f0f98b0d7c89","type":"Toolbar"},"x_range":{"id":"b7995dcd-0abe-4e68-add4-80fa7e505881","type":"DataRange1d"},"y_range":{"id":"29f32180-753f-465c-ab52-9c8f90b5a0ef","type":"DataRange1d"}},"id":"240521ee-1eb9-4fb9-831f-ae1cf72b8723","subtype":"Figure","type":"Plot"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f35c76f3-47bd-4e9b-a630-127f36f2ad57","type":"Line"},{"attributes":{},"id":"7900588e-37ff-4950-8adb-2f904bf6e4f6","type":"ToolEvents"},{"attributes":{"callback":null},"id":"b7995dcd-0abe-4e68-add4-80fa7e505881","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"3cbd2874-ac1b-4e01-886e-c3013b8a4d77","type":"PanTool"},{"id":"b513a5ba-1525-4e3c-a690-c54c648c1805","type":"WheelZoomTool"},{"id":"49cf8ea0-a66b-4a94-9c93-bd23d2559a17","type":"BoxZoomTool"},{"id":"c6de17d5-e001-4bf7-beab-7f39b37f62c6","type":"SaveTool"},{"id":"541c1f5f-9f5f-4677-aecc-dfbf36420f9d","type":"ResetTool"},{"id":"bca19957-44e2-435c-a46b-53657a7fe89d","type":"HelpTool"}]},"id":"11abcdf8-b36d-418e-bce9-f0f98b0d7c89","type":"Toolbar"},{"attributes":{"callback":null},"id":"29f32180-753f-465c-ab52-9c8f90b5a0ef","type":"DataRange1d"},{"attributes":{"formatter":{"id":"d7192560-c2b2-405d-a88c-37e801da733b","type":"BasicTickFormatter"},"plot":{"id":"240521ee-1eb9-4fb9-831f-ae1cf72b8723","subtype":"Figure","type":"Plot"},"ticker":{"id":"018f0b4d-f3cc-42b1-a571-6bab08fb206c","type":"BasicTicker"}},"id":"4558ba12-0491-4d56-afbe-90b54ee9630d","type":"LinearAxis"},{"attributes":{},"id":"018f0b4d-f3cc-42b1-a571-6bab08fb206c","type":"BasicTicker"},{"attributes":{"plot":{"id":"240521ee-1eb9-4fb9-831f-ae1cf72b8723","subtype":"Figure","type":"Plot"},"ticker":{"id":"018f0b4d-f3cc-42b1-a571-6bab08fb206c","type":"BasicTicker"}},"id":"dd18e947-ff7c-4082-a5b3-16f0c29bf9ec","type":"Grid"},{"attributes":{"formatter":{"id":"605edd31-af5a-4760-b0a9-b9e529dc57db","type":"Basi ...

# %% [markdown]
# Whilst this looks reasonable for $\sigma$ not very far from its original value, the more it differs the worse the "varied" binomial distribution looks. There has to be another way.
#
# As our main goal was to decrease the standard deviation of a binomial distribution let us to begin with keep this method and make it available through a function call.

# %%
def alberti_distribution(n, sigma):
    
    mu = n/2
    # The new normal distribution
    new_norm = normal_distribution(mu, sigma)
    # The binomial distribution for n
    bin = binomial_distribution(n)
    # The normal distribution with the binomial distribution's sigma 
    bin_sigma = sqrt(sum(bin(i)*(i-mu)**2 for i in range(n+1)))
    bin_norm = normal_distribution(mu, bin_sigma)
    
    def diff_to_integ(val, lower_bound=False):
        def f(a):
            # Set lower bound depending on whether it is specified or not
            lower = val-a if not lower_bound else lower_bound
            # Return value of integral minus the corresponding value of the binomial distribution
            return integrate(norm, lower, val+a) - bin(val)

        return f
        
    ## Calculating the interval boundaries
    
    interval_boundaries = []
   
    # Here we have to behave differently depending on whether n is even or odd
    if int(mu) == mu:
        a = solve(diff_to_integ(ceil(mu)), 0)[0]
    else:
        a = solve(diff_to_integ(ceil(mu), lower_bound=mu), 0)[0]
        interval_boundaries.append(mu)
    interval_boundaries.append(ceil(mu)+a)
    
    # Calculate the rest of the boundaries
    for i in range(int(ceil(mu))+1, n):
        lower_bound = interval_boundaries[-1]
        a = solve(diff_to_integ(i, lower_bound=lower_bound), 0)[0]
        interval_boundaries.append(i+a)
    
    # Mirroring for the other side
    other_side = n - arr(interval_boundaries)[::-1]
    # Another moment where a differentiation between even and odd n is to be made
    if int(mu) == mu:
        interval_boundaries = np.concatenate((other_side, interval_boundaries))
    else:
        interval_boundaries = np.concatenate((other_side, interval_boundaries[1::]))
    # Adding +/- infinity to the list
    interval_boundaries = list(interval_boundaries)
    interval_boundaries.insert(0, -inf)
    interval_boundaries.append(inf)
       
    # Calculating the corresponding integrals
    vals = []
    for i in range(n+1):
        vals.append(integrate(new_norm, interval_boundaries[i], interval_boundaries[i+1])[0])
    vals = arr(vals)

    def f(x):
        return vals[x]
    
    return f

# %%
p = fig()
dist1 = alberti_distribution(20, 10)
dist2 = alberti_distribution(20, 5)
dist3 = binomial_distribution(20)
x_vals = arr(range(21))
p.vbar(x_vals, top=dist3(x_vals), width=0.8)
p.line(x_norm, dist1(round(x_norm)), color="red")
show(p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-163-234aa41523b5> in <module>()
#       5 x_vals = arr(range(21))
#       6 p.vbar(x_vals, top=dist3(x_vals), width=0.8)
# ----> 7 p.line(x_norm, dist1(round(x_norm)), color="red")
#       8 show(p)
#
# <ipython-input-162-8d1a4af0ba49> in f(x)
#      56
#      57     def f(x):
# ---> 58         return integrate(new_norm, interval_boundaries[int(x)], interval_boundaries[int(x+1)])[0]
#      59
#      60     return f
#
# TypeError: only length-1 arrays can be converted to Python scalars
