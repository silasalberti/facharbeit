# %% [markdown]
# # Normal distribution
#
# This notebook examines the *normal distribution* and how it can be used to generate *binomial distributions* $B(n,p)$ with lower standard deviations $\sigma$ independent of $n$.

# %%
from sympy import init_session
import numpy as np
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
init_session()
output_notebook()
# Out:
# IPython console for SymPy 1.0 (Python 3.6.1-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at http://docs.sympy.org/1.0/
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8ba300e9-2fa3-487c-896d-f98501d56900">Loading BokehJS ...</span>
#     </div>

# %%
x = symbols('x')
sigma, mu = symbols('\sigma \mu')

# %%
normal_distribution = 1/sqrt(2*pi*sigma)*exp(-(x-mu)**2/(2*sigma**2))
normal_distribution
# Out:
#                2
#     -(-\mu + x)
#     ─────────────
#               2
#       2⋅\sigma
# √2⋅ℯ
# ─────────────────
#         ________
#  2⋅√π⋅╲╱ \sigma

# %%
lam_normal_distribution = lambdify(x, normal_distribution.subs([(mu,0),(sigma,6)]), modules=['numpy'])

# %%
x_vals = np.linspace(-20, 20, 1000)
y_vals = lam_normal_distribution(x_vals)

# %%
p = figure(plot_width=1000, plot_height=400)
p.line(x_vals, y_vals, line_width=2)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8cf0b0e2-7ead-4452-8618-19d75141a68d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8cf0b0e2-7ead-4452-8618-19d75141a68d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8cf0b0e2-7ead-4452-8618-19d75141a68d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8cf0b0e2-7ead-4452-8618-19d75141a68d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2836bccb-bd00-4b6e-9530-655cb99743b5":{"roots":{"references":[{"attributes":{},"id":"0df33b89-d924-49a0-bc14-915adc58adff","type":"BasicTicker"},{"attributes":{"formatter":{"id":"c02ea707-a7a8-4bfb-b38c-1e0c43131e01","type":"BasicTickFormatter"},"plot":{"id":"bd43f9cd-aad1-4a55-aee9-cd1a76f34fbe","subtype":"Figure","type":"Plot"},"ticker":{"id":"e1903cb2-76f7-42cc-a188-2a750b7d9ae0","type":"BasicTicker"}},"id":"66ee4ce4-4564-4db3-a710-f873088fd597","type":"LinearAxis"},{"attributes":{"formatter":{"id":"f65df978-9381-44ef-ae16-a1737f4a18cd","type":"BasicTickFormatter"},"plot":{"id":"bd43f9cd-aad1-4a55-aee9-cd1a76f34fbe","subtype":"Figure","type":"Plot"},"ticker":{"id":"0df33b89-d924-49a0-bc14-915adc58adff","type":"BasicTicker"}},"id":"9a3d511b-1c27-45a1-af69-3252c49a5738","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"53831e74-aacc-4ab5-a21a-f31810ce02b3","type":"PanTool"},{"id":"df8f2535-0a93-462b-a6da-45e00c6de5df","type":"WheelZoomTool"},{"id":"9d854f42-6185-4e5d-b147-fde3c02a2800","type":"BoxZoomTool"},{"id":"ccab77e1-1807-42bf-9671-9a3f9b1c0825","type":"SaveTool"},{"id":"1ab75a8a-6020-414b-9f15-51d178aea285","type":"ResetTool"},{"id":"72b76261-307c-4d18-9fcb-7e7828932d20","type":"HelpTool"}]},"id":"69d37134-3b8d-4762-bf64-61bcfe797b8d","type":"Toolbar"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"1904b412-a8d5-44ba-9c7a-7a3556b1248d","type":"ColumnDataSource"},{"attributes":{},"id":"e1903cb2-76f7-42cc-a188-2a750b7d9ae0","type":"BasicTicker"},{"attributes":{"callback":null},"id":"d00e0251-b386-4aff-bd89-cde17363aa0a","type":"DataRange1d"},{"attributes":{"callback":null},"id":"a8be9a2f-5e53-43f8-afb1-81aaedd728bf","type":"DataRange1d"},{"attributes":{},"id":"c02ea707-a7a8-4bfb-b38c-1e0c43131e01","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"9a3d511b-1c27-45a1-af69-3252c49a5738","type":"LinearAxis"}],"left":[{"id":"66ee4ce4-4564-4db3-a710-f873088fd597","type":"LinearAxis"}],"plot_height":400,"plot_width":1000,"renderers":[{"id":"9a3d511b-1c27-45a1-af69-3252c49a5738","type":"LinearAxis"},{"id":"e6919c40-51ef-4a00-9c18-2cdca1b47bbd","type":"Grid"},{"id":"66ee4ce4-4564-4db3-a710-f873088fd597","type":"LinearAxis"},{"id":"66440e37-04ff-43e3-b3cf-669ce5bf18b0","type":"Grid"},{"id":"bd7e742b-63b1-4545-ba68-67ab00cc40cd","type":"BoxAnnotation"},{"id":"1b9d0f14-71f5-4113-815f-b0f2cf1c8df3","type":"GlyphRenderer"}],"title":{"id":"0a10613f-77e4-42fe-88e1-c81d65d9b7c8","type":"Title"},"tool_events":{"id":"1a8b1525-e481-46c8-b7d2-f0f51f350e9f","type":"ToolEvents"},"toolbar":{"id":"69d37134-3b8d-4762-bf64-61bcfe797b8d","type":"Toolbar"},"x_range":{"id":"a8be9a2f-5e53-43f8-afb1-81aaedd728bf","type":"DataRange1d"},"y_range":{"id":"d00e0251-b386-4aff-bd89-cde17363aa0a","type":"DataRange1d"}},"id":"bd43f9cd-aad1-4a55-aee9-cd1a76f34fbe","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"1a8b1525-e481-46c8-b7d2-f0f51f350e9f","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"bd43f9cd-aad1-4a55-aee9-cd1a76f34fbe","subtype":"Figure","type":"Plot"},"ticker":{"id":"e1903cb2-76f7-42cc-a188-2a750b7d9ae0","type":"BasicTicker"}},"id":"66440e37-04ff-43e3-b3cf-669ce5bf18b0","type":"Grid"},{"attributes":{"overlay":{"id":"bd7e742b-63b1-4545-ba68-67ab00cc40cd","type":"BoxAnnotation"},"plot":{"id":"bd43f9cd-aad1-4a55-aee9-cd1a76f34fbe","subtype":"Figure","type":"Plot"}},"id":"9d854f42-6185-4e5d-b147-fde3c02a2800","type":"BoxZoomTool"},{"attributes":{},"id":"f65df978-9381-44ef-ae16-a1737f4a18cd","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"bd43f9cd-aad1-4a55-aee9-cd1a76f34fbe","subtype":"Figure","type":"Plot"}},"id":"53831e74-aacc-4ab5-a21a-f31810ce02b3","type":"PanTool"},{"attributes":{"plot":{"id":"bd43f9cd-aad1-4a55-aee9-cd1a76f34fbe","subtype":"Figure","type":"Plot"}},"i ...
