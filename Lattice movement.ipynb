# %% [markdown]
# # Lattice movement
# This notebook aims at providing tools for simulating the movement of particles in a lattice.

# %%
import numpy as np
from bokeh.plotting import figure, show, output_notebook, ColumnDataSource
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="51a9c270-b911-48b6-8c01-3709f6c6a85e">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# The "hat" function is defined as follows:
# $$ \hat{x}:=Re(x)+Im(x) $$

# %%
def hat(z):
    return z.real + z.imag

# %%
x = np.linspace(0,10,100)
y = x**2

p = figure()
p.line(x,y)
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="5c8a8ab7-494d-488b-96cf-a9046ce48458"></div>
# </div>

# %%
N = 9
x = np.linspace(0, 9, 10) + 0.5
y = 0*x + 0.5
w = 0*x + 0.9
h = 0*x + 0.9

source = ColumnDataSource(dict(x=x, y=y, w=w, h=h))

# %%
p = figure()
p.rect(x=x, y=y, width=w, height=h)
p.line(x=np.linspace(0,10,100), y=np.linspace(0,10,100))
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1a344fcf-83d0-4a8e-b20d-88d5c711d62a"></div>
# </div>
